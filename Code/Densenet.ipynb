# %% [markdown]
# # **Import**

# %%
import os
import random
import time
import datetime
from pathlib import Path

import numpy as np
import pandas as pd
from PIL import Image

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import torchvision.models as models
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from torchinfo import summary
from tqdm import tqdm
import logging

# %%
GPU_NUM = 1
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)

# %% [markdown]
# # **Config**

# %%
CFG = {
    "IMG_SIZE": 224,
    "NUM_CLASSES": 396,
    "BATCH_SIZE": 32,
    "EPOCHS": 500,
    "LR": 1e-4,
    "WEIGHT_DECAY": 1e-2,
    "PATIENCE": 5,
    "SEED": 42,
    # AMP & Grad‑clip
    "USE_AMP": False,
    "GRAD_CLIP": 1.0,
}

BASE_DIR = Path(r"D:/dacon_HAI")
PATHS = {
    "BASE": BASE_DIR,
    "TRAIN": BASE_DIR / "open" / "train",
    "TEST":  BASE_DIR / "open" / "test",
    "CKPT":  BASE_DIR / "checkpoints",
    "LOG":   BASE_DIR / "logs",
    "SUBMIT": BASE_DIR / "submission",
}
for p in PATHS.values():
    p.mkdir(parents=True, exist_ok=True)

# --- Normalization stats ---
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
seed_everything(CFG["SEED"])

# %% [markdown]
# # **Dataloader**

# %%
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None, is_test=False):
        self.root_dir = root_dir
        self.transform = transform
        self.is_test = is_test
        self.samples = []

        if self.is_test:
            for fname in sorted(os.listdir(root_dir)):
                if fname.lower().endswith('.jpg'):
                    img_path = os.path.join(root_dir, fname)
                    self.samples.append((img_path,))
        else:
            self.classes = sorted(os.listdir(root_dir))
            self.class_to_idx = {cls_name: idx for idx, cls_name in enumerate(self.classes)}
            for cls_name in self.classes:
                cls_folder = os.path.join(root_dir, cls_name)
                for fname in os.listdir(cls_folder):
                    if fname.lower().endswith('.jpg'):
                        img_path = os.path.join(cls_folder, fname)
                        label = self.class_to_idx[cls_name]
                        self.samples.append((img_path, label))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        if self.is_test:
            img_path = self.samples[idx][0]
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            return image, os.path.basename(img_path)
        else:
            img_path, label = self.samples[idx]
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)
            return image, label

spatial_aug = transforms.RandomChoice([
    transforms.RandomResizedCrop(CFG["IMG_SIZE"], scale=(0.8, 1.0)),
    transforms.CenterCrop(CFG["IMG_SIZE"]),
])
geom_aug = transforms.RandomChoice([
    transforms.RandomHorizontalFlip(p=1.0),
    transforms.RandomVerticalFlip(p=1.0),
    transforms.RandomRotation(degrees=(-30, 30), interpolation=transforms.InterpolationMode.BILINEAR, fill=0),
])
pixel_aug = transforms.RandomChoice([
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.1),
    transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 5.0)),
    transforms.RandomAdjustSharpness(sharpness_factor=2),
])

train_tf = transforms.Compose([
    transforms.Resize((CFG["IMG_SIZE"], CFG["IMG_SIZE"])),
    transforms.RandomApply([spatial_aug], p=0.5),
    transforms.RandomApply([geom_aug],    p=0.5),
    transforms.RandomApply([pixel_aug],   p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])
val_tf = transforms.Compose([
    transforms.Resize((CFG["IMG_SIZE"], CFG["IMG_SIZE"])),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
full_ds = CustomImageDataset(PATHS["TRAIN"], transform=train_tf, is_test=False)
print(f"Full data: {len(full_ds):,}")

targets = [label for _, label in full_ds.samples]
class_names = full_ds.classes

train_idx, val_idx = train_test_split(
    np.arange(len(targets)),
    test_size=0.2,
    stratify=targets,
    random_state=CFG['SEED']
)


train_dataset = Subset(CustomImageDataset(PATHS["TRAIN"], transform=train_tf, is_test=False), train_idx)
val_dataset = Subset(CustomImageDataset(PATHS["TRAIN"], transform=val_tf, is_test=False), val_idx)


train_loader = DataLoader(train_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=True, num_workers=0)
val_loader   = DataLoader(val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)


test_root = PATHS["TEST"]
test_dataset = CustomImageDataset(test_root, transform=val_tf, is_test=True)
test_loader  = DataLoader(test_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)


print(f"Number of train imgs: {len(train_dataset)}, Number of valid imgs: {len(val_dataset)}")

# %% [markdown]
# # **Network**

# %% [markdown]
# ### densenet121

# %%
class DenseNetModel(nn.Module):
    def __init__(self, num_classes):
        super(DenseNetModel, self).__init__()
        self.backbone = models.densenet121(pretrained=True)
        in_features = self.backbone.classifier.in_features
        self.backbone.classifier = nn.Identity()
        self.head = nn.Linear(in_features, num_classes)

    def forward(self, x):
        x = self.backbone(x)
        x = self.head(x)
        return x

# %%
model = DenseNetModel(num_classes=CFG['NUM_CLASSES'])
print(summary(model, input_size=(1, 3, CFG["IMG_SIZE"], CFG["IMG_SIZE"],)))
# Out:
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# DenseNetModel                                 [1, 396]                  --
# ├─DenseNet: 1-1                               [1, 1024]                 --
# │    └─Sequential: 2-1                        [1, 1024, 7, 7]           --
# │    │    └─Conv2d: 3-1                       [1, 64, 112, 112]         9,408
# │    │    └─BatchNorm2d: 3-2                  [1, 64, 112, 112]         128
# │    │    └─ReLU: 3-3                         [1, 64, 112, 112]         --
# │    │    └─MaxPool2d: 3-4                    [1, 64, 56, 56]           --
# │    │    └─_DenseBlock: 3-5                  [1, 256, 56, 56]          335,040
# │    │    └─_Transition: 3-6                  [1, 128, 28, 28]          33,280
# │    │    └─_DenseBlock: 3-7                  [1, 512, 28, 28]          919,680
# │    │    └─_Transition: 3-8                  [1, 256, 14, 14]          132,096
# │    │    └─_DenseBlock: 3-9                  [1, 1024, 14, 14]         2,837,760
# │    │    └─_Transition: 3-10                 [1, 512, 7, 7]            526,336
# │    │    └─_DenseBlock: 3-11                 [1, 1024, 7, 7]           2,158,080
# │    │    └─BatchNorm2d: 3-12                 [1, 1024, 7, 7]           2,048
# │    └─Identity: 2-2                          [1, 1024]                 --
# ├─Linear: 1-2                                 [1, 396]                  405,900
# ===============================================================================================
# Total params: 7,359,756
# Trainable params: 7,359,756
# Non-trainable params: 0
# Total mult-adds (G): 2.83
# ===============================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 180.54
# Params size (MB): 29.44
# Estimated Total Size (MB): 210.58
# ===============================================================================================

# %% [markdown]
# # **Hyper-params**

# %%
model = model.to(device)

optimizer = optim.AdamW(model.parameters(), lr=CFG["LR"], weight_decay=CFG["WEIGHT_DECAY"])

steps_per_epoch = len(train_loader)
warmup_steps = 5 * steps_per_epoch

def lr_lambda(step):
    if step < warmup_steps:
        return step / float(max(1, warmup_steps))
    progress = (step - warmup_steps) / float(max(1, CFG["EPOCHS"] * steps_per_epoch - warmup_steps))
    return 0.5 * (1.0 + torch.cos(torch.pi * torch.tensor(progress)))

scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
criterion = nn.CrossEntropyLoss()

# %%
class EarlyStopping:
    def __init__(self, patience: int = 5, delta: float = 0.0):
        self.patience = patience
        self.delta = delta
        self.best = None
        self.counter = 0
        self.stop = False

    def __call__(self, metric: float):
        if self.best is None or metric < self.best - self.delta:
            self.best = metric
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop = True

early_stopper = EarlyStopping(patience=CFG["PATIENCE"], delta=0.001)


log_file = PATHS["LOG"] / "train_densenet.log"
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(message)s",
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler(log_file, mode="w"),
    ],
)
logger = logging.getLogger()

# %% [markdown]
# # **Train net**

# %%
def train_one_epoch(epoch):
    model.train()
    running_loss = 0.0
    pbar = tqdm(train_loader, desc=f"[{epoch}/{CFG['EPOCHS']}] Train", leave=False)
    for step, (imgs, labels) in enumerate(pbar, start=1):
        imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        optimizer.zero_grad(set_to_none=True)
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

        running_loss += loss.item()
        pbar.set_postfix({"loss": f"{loss.item():.4f}", "lr": f"{scheduler.get_last_lr()[0]:.4f}"})

    return running_loss / len(train_loader)

def validate(epoch):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    all_probs, all_labels = [], []
    with torch.no_grad():
        for imgs, labels in val_loader:
            imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            logits = model(imgs)
            loss = criterion(logits, labels)
            
            val_loss += loss.item()
            preds = logits.argmax(1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_probs.append(F.softmax(logits, dim=1).cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    acc = 100. * correct / total
    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)

    class_idx = list(range(CFG["NUM_CLASSES"]))
    answer_df = pd.DataFrame({"ID": np.arange(len(all_labels)), "label": all_labels})
    submission_df = pd.DataFrame(all_probs, columns=class_idx)
    submission_df.insert(0, "ID", submission_df.index)
    avg_val_loss = val_loss / len(val_loader)
    logloss = log_loss(answer_df["label"], all_probs, labels=class_idx)

    return avg_val_loss, acc, logloss



BEST_LOSS = float("inf")
start = time.time()
for epoch in range(1, CFG["EPOCHS"] + 1):
    t0 = time.time()
    tr_loss = train_one_epoch(epoch)
    val_loss, val_acc, val_logloss = validate(epoch)
    epoch_dur = time.time() - t0

    logger.info(
        f"Epoch {epoch}/{CFG['EPOCHS']} | "
        f"Time {epoch_dur:.1f}s | "
        f"TrainLoss {tr_loss:.4f} | ValLoss {val_loss:.4f} | "
        f"ValAcc {val_acc:.2f}% | LogLoss {val_logloss:.4f}"
    )

    # Save best by logloss
    if val_logloss < BEST_LOSS:
        BEST_LOSS = val_logloss
        ckpt_path = PATHS["CKPT"] / "best_densenet.pth"
        torch.save(model.state_dict(), ckpt_path)
        logger.info(f"[Checkpoint] Saved at epoch {epoch} (LogLoss {BEST_LOSS:.4f})")

    early_stopper(val_logloss)
    if early_stopper.stop:
        logger.info("Early stopping triggered.")
        break

logger.info(f"Total training time: {datetime.timedelta(seconds=int(time.time() - start))}")
# Out:
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:2: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=CFG["USE_AMP"])
# [1/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 11:14:56,509 Epoch 1/500 | Time 439.1s | TrainLoss 6.0017 | ValLoss 5.7908 | ValAcc 3.25% | LogLoss 5.7635
# 2025-06-11 11:14:56,683 [Checkpoint] Saved at epoch 1 (LogLoss 5.7635)
# [2/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 11:23:17,983 Epoch 2/500 | Time 501.3s | TrainLoss 5.4297 | ValLoss 4.6416 | ValAcc 30.83% | LogLoss 4.4615
# 2025-06-11 11:23:18,159 [Checkpoint] Saved at epoch 2 (LogLoss 4.4615)
# [3/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 11:30:44,770 Epoch 3/500 | Time 446.6s | TrainLoss 4.1767 | ValLoss 3.0375 | ValAcc 63.57% | LogLoss 2.6114
# 2025-06-11 11:30:44,933 [Checkpoint] Saved at epoch 3 (LogLoss 2.6114)
# [4/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 11:37:59,748 Epoch 4/500 | Time 434.8s | TrainLoss 2.7528 | ValLoss 1.8719 | ValAcc 79.42% | LogLoss 1.1940
# 2025-06-11 11:37:59,911 [Checkpoint] Saved at epoch 4 (LogLoss 1.1940)
# [5/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 11:45:24,045 Epoch 5/500 | Time 444.1s | TrainLoss 1.8365 | ValLoss 1.4770 | ValAcc 86.14% | LogLoss 0.6771
# 2025-06-11 11:45:24,275 [Checkpoint] Saved at epoch 5 (LogLoss 0.6771)
# [6/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 12:02:58,141 Epoch 6/500 | Time 1053.9s | TrainLoss 1.4596 | ValLoss 1.3106 | ValAcc 90.75% | LogLoss 0.4671
# 2025-06-11 12:02:58,328 [Checkpoint] Saved at epoch 6 (LogLoss 0.4671)
# [7/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 12:26:40,983 Epoch 7/500 | Time 1422.7s | TrainLoss 1.3034 | ValLoss 1.2332 | ValAcc 92.48% | LogLoss 0.3641
# 2025-06-11 12:26:41,171 [Checkpoint] Saved at epoch 7 (LogLoss 0.3641)
# [8/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 12:50:22,758 Epoch 8/500 | Time 1421.6s | TrainLoss 1.2238 | ValLoss 1.2082 | ValAcc 92.60% | LogLoss 0.3334
# 2025-06-11 12:50:22,926 [Checkpoint] Saved at epoch 8 (LogLoss 0.3334)
# [9/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 13:10:50,751 Epoch 9/500 | Time 1227.8s | TrainLoss 1.1799 | ValLoss 1.1910 | ValAcc 92.93% | LogLoss 0.3101
# 2025-06-11 13:10:50,963 [Checkpoint] Saved at epoch 9 (LogLoss 0.3101)
# [10/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 13:27:27,277 Epoch 10/500 | Time 996.3s | TrainLoss 1.1463 | ValLoss 1.1641 | ValAcc 94.08% | LogLoss 0.3074
# 2025-06-11 13:27:27,446 [Checkpoint] Saved at epoch 10 (LogLoss 0.3074)
# [11/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 13:40:19,657 Epoch 11/500 | Time 772.2s | TrainLoss 1.1254 | ValLoss 1.1507 | ValAcc 94.76% | LogLoss 0.2847
# 2025-06-11 13:40:19,817 [Checkpoint] Saved at epoch 11 (LogLoss 0.2847)
# [12/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 13:50:38,048 Epoch 12/500 | Time 618.2s | TrainLoss 1.1059 | ValLoss 1.1422 | ValAcc 94.97% | LogLoss 0.2842
# 2025-06-11 13:50:38,223 [Checkpoint] Saved at epoch 12 (LogLoss 0.2842)
# [13/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 14:02:02,946 Epoch 13/500 | Time 684.7s | TrainLoss 1.0928 | ValLoss 1.1288 | ValAcc 95.18% | LogLoss 0.2578
# 2025-06-11 14:02:03,130 [Checkpoint] Saved at epoch 13 (LogLoss 0.2578)
# [14/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 14:17:15,781 Epoch 14/500 | Time 912.6s | TrainLoss 1.0775 | ValLoss 1.1354 | ValAcc 95.10% | LogLoss 0.2728
# [15/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 14:33:36,399 Epoch 15/500 | Time 980.6s | TrainLoss 1.0686 | ValLoss 1.1200 | ValAcc 95.39% | LogLoss 0.2559
# 2025-06-11 14:33:36,593 [Checkpoint] Saved at epoch 15 (LogLoss 0.2559)
# [16/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 14:49:43,376 Epoch 16/500 | Time 966.8s | TrainLoss 1.0594 | ValLoss 1.1081 | ValAcc 96.07% | LogLoss 0.2607
# [17/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 15:06:15,608 Epoch 17/500 | Time 992.2s | TrainLoss 1.0516 | ValLoss 1.1021 | ValAcc 96.13% | LogLoss 0.2488
# 2025-06-11 15:06:15,830 [Checkpoint] Saved at epoch 17 (LogLoss 0.2488)
# [18/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 15:22:34,933 Epoch 18/500 | Time 979.1s | TrainLoss 1.0430 | ValLoss 1.0977 | ValAcc 96.19% | LogLoss 0.2435
# 2025-06-11 15:22:35,118 [Checkpoint] Saved at epoch 18 (LogLoss 0.2435)
# [19/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 15:38:50,499 Epoch 19/500 | Time 975.4s | TrainLoss 1.0402 | ValLoss 1.0930 | ValAcc 96.09% | LogLoss 0.2307
# 2025-06-11 15:38:50,687 [Checkpoint] Saved at epoch 19 (LogLoss 0.2307)
# [20/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 15:55:26,663 Epoch 20/500 | Time 996.0s | TrainLoss 1.0328 | ValLoss 1.1017 | ValAcc 95.77% | LogLoss 0.2499
# [21/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 16:11:49,685 Epoch 21/500 | Time 983.0s | TrainLoss 1.0277 | ValLoss 1.0922 | ValAcc 96.33% | LogLoss 0.2452
# [22/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 16:28:27,934 Epoch 22/500 | Time 998.2s | TrainLoss 1.0204 | ValLoss 1.0883 | ValAcc 96.18% | LogLoss 0.2412
# [23/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 16:42:38,086 Epoch 23/500 | Time 850.2s | TrainLoss 1.0186 | ValLoss 1.0883 | ValAcc 96.28% | LogLoss 0.2376
# [24/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 16:53:06,297 Epoch 24/500 | Time 628.2s | TrainLoss 1.0143 | ValLoss 1.0836 | ValAcc 96.42% | LogLoss 0.2209
# 2025-06-11 16:53:06,514 [Checkpoint] Saved at epoch 24 (LogLoss 0.2209)
# [25/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:02:48,841 Epoch 25/500 | Time 582.3s | TrainLoss 1.0100 | ValLoss 1.0925 | ValAcc 96.19% | LogLoss 0.2442
# [26/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:11:47,077 Epoch 26/500 | Time 538.2s | TrainLoss 1.0078 | ValLoss 1.0832 | ValAcc 96.48% | LogLoss 0.2527
# [27/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:20:03,291 Epoch 27/500 | Time 496.2s | TrainLoss 1.0029 | ValLoss 1.0808 | ValAcc 96.49% | LogLoss 0.2476
# [28/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:27:23,760 Epoch 28/500 | Time 440.5s | TrainLoss 1.0008 | ValLoss 1.0755 | ValAcc 96.55% | LogLoss 0.2293
# [29/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:33:44,391 Epoch 29/500 | Time 380.6s | TrainLoss 0.9974 | ValLoss 1.0765 | ValAcc 96.72% | LogLoss 0.2177
# 2025-06-11 17:33:44,549 [Checkpoint] Saved at epoch 29 (LogLoss 0.2177)
# [30/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:39:27,791 Epoch 30/500 | Time 343.2s | TrainLoss 0.9960 | ValLoss 1.0748 | ValAcc 96.65% | LogLoss 0.2308
# [31/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:45:25,345 Epoch 31/500 | Time 357.6s | TrainLoss 0.9961 | ValLoss 1.0741 | ValAcc 96.62% | LogLoss 0.2468
# [32/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:51:01,932 Epoch 32/500 | Time 336.6s | TrainLoss 0.9894 | ValLoss 1.0823 | ValAcc 96.71% | LogLoss 0.2339
# [33/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 17:56:33,407 Epoch 33/500 | Time 331.5s | TrainLoss 0.9900 | ValLoss 1.0796 | ValAcc 96.46% | LogLoss 0.2336
# [34/500] Train:   0%|          | 0/828 [00:00<?, ?it/s]C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:11: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# C:\Users\USPD\AppData\Local\Temp\ipykernel_53860\2593035775.py:36: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=CFG["USE_AMP"]):
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\preprocessing\_label.py:302: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   self.y_type_ = type_of_target(y, input_name="y")
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\sklearn\utils\multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples.
#   ys_types = set(type_of_target(x) for x in ys)
# 2025-06-11 18:02:24,749 Epoch 34/500 | Time 351.3s | TrainLoss 0.9869 | ValLoss 1.0681 | ValAcc 96.87% | LogLoss 0.2279
# 2025-06-11 18:02:24,751 Early stopping triggered.
# 2025-06-11 18:02:24,751 Total training time: 6:54:47

# %% [markdown]
# # **Eval**

# %%
model = DenseNetModel(num_classes=CFG['NUM_CLASSES'])
model.load_state_dict(torch.load(PATHS["CKPT"] / "best_densenet.pth", map_location=device))
model.to(device)
model.eval()

results = []

with torch.no_grad():
    for images, filenames in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)

        for prob in probs.cpu():
            result = {
                class_names[i]: prob[i].item()
                for i in range(len(class_names))
            }
            results.append(result)
            
pred = pd.DataFrame(results)
# Out:
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\USPD\anaconda3\envs\hai_env\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Submission
submission = pd.read_csv(os.path.join(PATHS["SUBMIT"], 'submission_JN.csv'), encoding='utf-8-sig')

class_columns = submission.columns[1:]
pred = pred[class_columns]

submission[class_columns] = pred.values
submission.to_csv(os.path.join(PATHS["SUBMIT"], 'densenet_b32_submission_JN.csv'), index=False, encoding='utf-8-sig')
